# %% [markdown]
# <a href="https://colab.research.google.com/github/verammaz/KMeans-VAE/blob/main/run_in_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # KMeans Pipeline on Google Colab

# %% [markdown]
# ## Setup & Installation

# %%
# Install required packages
! pip install -q torch sklearn tqdm matplotlib wandb

print("Packages installed successfully!")

# %% [markdown]
# ## Clone GitHub Repo

# %%
! git clone https://github.com/verammaz/KMeans-VAE.git
# %cd KMeans-VAE

# %% [markdown]
# ## Run Kmeans Pipeline
#
# 1. Kmeans in original input space
# 2. Kmeans in latent space

# %%
DATA_DIR = './datasets/gaussian_raw'
VAE_PATH = './out/vae_gaus_i64_k5_z10_beta1.0/model.pt'

! python -m kmeans.main --data_dir {DATA_DIR} --vae_path {VAE_PATH}
# Out:
# /Users/veramazeeva/Library/CloudStorage/OneDrive-Personal/Columbia/UML/KMeans-VAE/kmeans/main.py:51: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(vae_path, map_location=DEVICE)
# /Users/veramazeeva/Library/CloudStorage/OneDrive-Personal/Columbia/UML/KMeans-VAE/kmeans/main.py:86: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   z_mean, _ = vae.encode(torch.tensor(X_test, dtype=torch.float32).to(DEVICE))
# Running kmeans in input space...
# /Users/veramazeeva/anaconda3/envs/ml_ai/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# Running kmeans in latent space...
# /Users/veramazeeva/anaconda3/envs/ml_ai/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
#
# === KMeans Comparison ===
# Input-space  ARI: 1.000, NMI: 1.000, Inertia: 941462.219
# Latent-space ARI: 1.000, NMI: 1.000, Inertia: 14636.228
#
# Results saved to /Users/veramazeeva/Library/CloudStorage/OneDrive-Personal/Columbia/UML/KMeans-VAE/out/vae_gaus_i64_k5_z10_beta1.0/kmeans_results
